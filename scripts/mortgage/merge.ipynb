# %%
import os
import pandas as pd

FILES = {
    "mortgage": "data/raw/mortgage_rates.csv",
    "listing": "data/processed/combined_listingsv2.csv",
    "sold": "data/processed/combined_soldv2.csv",
}


base_dir = os.path.dirname((os.path.dirname(os.path.abspath(""))))

sold = pd.read_csv(os.path.join(base_dir, FILES["sold"]))
listing = pd.read_csv(os.path.join(base_dir, FILES["listing"]))
mortgage = pd.read_csv(os.path.join(base_dir, FILES["mortgage"]))
# Out:
# /var/folders/dc/245wkwwd22jf9mtnyn_s6_pr0000gn/T/ipykernel_80344/3606788983.py:13: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv(os.path.join(base_dir, FILES["sold"]))

# %% [markdown]
# Convert to `datetime64`

# %%
sold['year_month'] = pd.to_datetime(sold['CloseDate']).dt.to_period('M')
listing['year_month'] = pd.to_datetime(listing['ListingContractDate']).dt.to_period('M')
mortgage['year_month'] = pd.to_datetime(mortgage['year_month']).dt.to_period('M')

# %% [markdown]
# Merging Lists

# %%
sold_with_rates = sold.merge(mortgage, on='year_month', how='left')
listings_with_rates = listing.merge(mortgage, on='year_month', how='left')

# %% [markdown]
# Sanity Check for rates

# %%
print(sold_with_rates['rate'].isnull().sum())
print(listings_with_rates['rate'].isnull().sum())
# Out:
# 0
# 0

# %%
print(sold_with_rates[['CloseDate', 'year_month', 'ClosePrice', 'rate']].head())
# Out:
#     CloseDate year_month  ClosePrice    rate
# 0  2024-04-16    2024-04   1360000.0  6.9925
# 1  2024-04-30    2024-04    413700.0  6.9925
# 2  2024-04-02    2024-04    250000.0  6.9925
# 3  2024-04-01    2024-04    526000.0  6.9925
# 4  2024-04-29    2024-04   1525000.0  6.9925

# %%
sold_with_rates.to_csv(os.path.join(base_dir, "data/processed/sold_with_rates.csv"), index=False)
listings_with_rates.to_csv(os.path.join(base_dir, "data/processed/listings_with_rates.csv"), index=False)
